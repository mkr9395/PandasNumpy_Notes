# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('pokemon.csv',encoding='latin-1')
df.drop('Serial',inplace=True,axis=1)

# %%
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.shape
# Out:
# (800, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   HP          800 non-null    int64
#  4   Attack      800 non-null    int64
#  5   Defense     800 non-null    int64
#  6   Sp. Atk     800 non-null    int64
#  7   Sp. Def     800 non-null    int64
#  8   Speed       800 non-null    int64
#  9   Generation  800 non-null    int64
#  10  Legendary   800 non-null    bool
# dtypes: bool(1), int64(7), object(3)
# memory usage: 63.4+ KB

# %%
df['Name']
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
df[['Name','Type 1','Attack','Type 2']]
# Out:
#                       Name   Type 1  Attack  Type 2
# 0                Bulbasaur    Grass      49  Poison
# 1                  Ivysaur    Grass      62  Poison
# 2                 Venusaur    Grass      82  Poison
# 3    VenusaurMega Venusaur    Grass     100  Poison
# 4               Charmander     Fire      52     NaN
# ..                     ...      ...     ...     ...
# 795                Diancie     Rock     100   Fairy
# 796    DiancieMega Diancie     Rock     160   Fairy
# 797    HoopaHoopa Confined  Psychic     110   Ghost
# 798     HoopaHoopa Unbound  Psychic     160    Dark
# 799              Volcanion     Fire     110   Water
#
# [800 rows x 4 columns]

# %% [markdown]
# ### iloc

# %%
df.iloc[-10:]
# Out:
#                     Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 790               Noibat   Flying  Dragon   40      30       35       45
# 791              Noivern   Flying  Dragon   85      70       80       97
# 792              Xerneas    Fairy     NaN  126     131       95      131
# 793              Yveltal     Dark  Flying  126     131       95      131
# 794     Zygarde50% Forme   Dragon  Ground  108     100      121       81
# 795              Diancie     Rock   Fairy   50     100      150      100
# 796  DiancieMega Diancie     Rock   Fairy   50     160      110      160
# 797  HoopaHoopa Confined  Psychic   Ghost   80     110       60      150
# 798   HoopaHoopa Unbound  Psychic    Dark   80     160       60      170
# 799            Volcanion     Fire   Water   80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 790       40     55           6      False
# 791       80    123           6      False
# ...

# %% [markdown]
# ##### list of rows and columns

# %%
df.iloc[[1,4,8,11,34],[0,1,4,6]]
# Out:
#                          Name  Type 1  Attack  Sp. Atk
# 1                     Ivysaur   Grass      62       80
# 4                  Charmander    Fire      52       60
# 8   CharizardMega Charizard Y    Fire     104      159
# 11                  Blastoise   Water      83       85
# 34           Nidoran (Female)  Poison      47       40

# %%
df.iloc[lambda x: x.index % 2 == 0]
# Out:
#                           Name   Type 1  Type 2   HP  Attack  Defense  \
# 0                    Bulbasaur    Grass  Poison   45      49       49
# 2                     Venusaur    Grass  Poison   80      82       83
# 4                   Charmander     Fire     NaN   39      52       43
# 6                    Charizard     Fire  Flying   78      84       78
# 8    CharizardMega Charizard Y     Fire  Flying   78     104       78
# ..                         ...      ...     ...  ...     ...      ...
# 790                     Noibat   Flying  Dragon   40      30       35
# 792                    Xerneas    Fairy     NaN  126     131       95
# 794           Zygarde50% Forme   Dragon  Ground  108     100      121
# 796        DiancieMega Diancie     Rock   Fairy   50     160      110
# 798         HoopaHoopa Unbound  Psychic    Dark   80     160       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.iloc[4,0]
# Out:
# 'Charmander'

# %% [markdown]
# #### Iteration through the data

# %%
for index, row in df.iterrows():
    print(row,index)
# Out:
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object 0
# Name          Ivysaur
# Type 1          Grass
# Type 2         Poison
# HP                 60
# Attack             62
# Defense            63
# Sp. Atk            80
# Sp. Def            80
# Speed              60
# Generation          1
# Legendary       False
# Name: 1, dtype: object 1
# Name          Venusaur
# Type 1           Grass
# Type 2          Poison
# HP                  80
# Attack              82
# Defense             83
# Sp. Atk            100
# Sp. Def            100
# Speed               80
# Generation           1
# Legendary        False
# Name: 2, dtype: object 2
# Name          VenusaurMega Venusaur
# Type 1                        Grass
# ...

# %% [markdown]
# #### loc

# %% [markdown]
# ##### loc on some condition

# %%
df.loc[df['Type 1']=='Fire']
# Out:
#                           Name Type 1    Type 2   HP  Attack  Defense  \
# 4                   Charmander   Fire       NaN   39      52       43
# 5                   Charmeleon   Fire       NaN   58      64       58
# 6                    Charizard   Fire    Flying   78      84       78
# 7    CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8    CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42                      Vulpix   Fire       NaN   38      41       40
# 43                   Ninetales   Fire       NaN   73      76       75
# 63                   Growlithe   Fire       NaN   55      70       45
# 64                    Arcanine   Fire       NaN   90     110       80
# 83                      Ponyta   Fire       NaN   50      85       55
# 84                    Rapidash   Fire       NaN   65     100       70
# 135                     Magmar   Fire       NaN   65      95       57
# ...

# %% [markdown]
# ### Sorting

# %%
df.sort_values(['Type 1','HP'],ascending=False)

# Both conditions are descending here
# Out:
#           Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 351    Wailord  Water     NaN  170      90       45       90       45     60
# 655  Alomomola  Water     NaN  165      75       80       40       45     65
# 142     Lapras  Water     Ice  130      85       80       85       95     60
# 145   Vaporeon  Water     NaN  130      65       60      110       95     65
# 350    Wailmer  Water     NaN  130      70       35       70       35     60
# ..         ...    ...     ...  ...     ...      ...      ...      ...    ...
# 314    Nincada    Bug  Ground   31      45       90       30       30     40
# 462     Combee    Bug  Flying   30      30       42       30       42     70
# 603   Venipede    Bug  Poison   30      45       59       30       39     57
# 230    Shuckle    Bug    Rock   20      10      230       10      230      5
# 316   Shedinja    Bug   Ghost    1      90       45       30       30     40
#
#      Generation  Legendary
# ...

# %% [markdown]
# #### One ascending other descending value

# %%
df.sort_values(['Type 1','HP'],ascending=[True,False])
# Out:
#                         Name Type 1    Type 2  HP  Attack  Defense  Sp. Atk  \
# 520                  Yanmega    Bug    Flying  86      76       86      116
# 698                Volcarona    Bug      Fire  85      60       65      135
# 231                Heracross    Bug  Fighting  80     125       75       40
# 232  HeracrossMega Heracross    Bug  Fighting  80     185      115       40
# 678                 Accelgor    Bug       NaN  80      70       40      100
# ..                       ...    ...       ...  ..     ...      ...      ...
# 106                   Krabby  Water       NaN  30     105       90       25
# 125                   Horsea  Water       NaN  30      40       70       70
# 129                   Staryu  Water       NaN  30      45       55       70
# 139                 Magikarp  Water       NaN  20      10       55       15
# 381                   Feebas  Water       NaN  20      15       20       10
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
col = list(df.columns.values)
col
# Out:
# ['Name',
#  'Type 1',
#  'Type 2',
#  'HP',
#  'Attack',
#  'Defense',
#  'Sp. Atk',
#  'Sp. Def',
#  'Speed',
#  'Generation',
#  'Legendary']

# %%
df[col]
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
df[col[:4]]
# Out:
#                       Name   Type 1  Type 2  HP
# 0                Bulbasaur    Grass  Poison  45
# 1                  Ivysaur    Grass  Poison  60
# 2                 Venusaur    Grass  Poison  80
# 3    VenusaurMega Venusaur    Grass  Poison  80
# 4               Charmander     Fire     NaN  39
# ..                     ...      ...     ...  ..
# 795                Diancie     Rock   Fairy  50
# 796    DiancieMega Diancie     Rock   Fairy  50
# 797    HoopaHoopa Confined  Psychic   Ghost  80
# 798     HoopaHoopa Unbound  Psychic    Dark  80
# 799              Volcanion     Fire   Water  80
#
# [800 rows x 4 columns]

# %% [markdown]
# ##### name contains Mega

# %%
df.loc[df['Name'].str.contains('Mega')].head()
# Out:
#                          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 3       VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 7   CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8   CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 12    BlastoiseMega Blastoise  Water     NaN  79     103      120      135
# 19      BeedrillMega Beedrill    Bug  Poison  65     150       40       15
#
#     Sp. Def  Speed  Generation  Legendary
# 3       120     80           1      False
# 7        85    100           1      False
# 8       115    100           1      False
# 12      115     78           1      False
# 19       80    145           1      False

# %% [markdown]
# ##### doesnot contains Mega

# %%
df.loc[~df['Name'].str.contains('Mega')].head()
# Out:
#          Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0   Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1     Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2    Venusaur  Grass  Poison  80      82       83      100      100     80
# 4  Charmander   Fire     NaN  39      52       43       60       50     65
# 5  Charmeleon   Fire     NaN  58      64       58       80       65     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False
# 4           1      False
# 5           1      False

# %% [markdown]
# #### Searching through Regular expression

# %%
import re

# %%
df.loc[df['Type 1'].str.contains('fire|grass', flags=re.I, regex=True)]

# flags=re.I ignore Case sentivity isssue
# Out:
#                       Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur  Grass    Poison   45      49       49       65
# 1                  Ivysaur  Grass    Poison   60      62       63       80
# 2                 Venusaur  Grass    Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass    Poison   80     100      123      122
# 48                  Oddish  Grass    Poison   45      50       55       75
# ..                     ...    ...       ...  ...     ...      ...      ...
# 718                Chespin  Grass       NaN   56      61       65       48
# 719              Quilladin  Grass       NaN   61      78       95       56
# 720             Chesnaught  Grass  Fighting   88     107      122       74
# 740                 Skiddo  Grass       NaN   66      65       48       62
# 741                 Gogoat  Grass       NaN  123     100       62       97
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Conditional Changes

# %% [markdown]
# ##### changing Fire to Flamer

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'

# %%
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0                Bulbasaur    Grass  Poison  45      49       49       65
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander   Flamer     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion   Flamer   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ### Na values/ Null values

# %% [markdown]
# #### Here are 4 ways to select all rows with NaN values in Pandas DataFrame:

# %% [markdown]
# ##### (1) Using isna() to select all rows with NaN under a single DataFrame column:

# %% [raw]
# df[df['column name'].isna()]

# %% [markdown]
# ##### (2) Using isnull() to select all rows with NaN under a single DataFrame column:

# %% [raw]
# df[df['column name'].isnull()]

# %% [markdown]
# ##### (3) Using isna() to select all rows with NaN under an entire DataFrame:

# %% [raw]
# df[df.isna().any(axis=1)]

# %% [markdown]
# ##### (4) Using isnull() to select all rows with NaN under an entire DataFrame:

# %% [raw]
# df[df.isnull().any(axis=1)]

# %% [markdown]
# ### Melt()

# %%
df1 = df.head(4)

# %%
df1
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
pd.melt(df1)
# Out:
#       variable                  value
# 0         Name              Bulbasaur
# 1         Name                Ivysaur
# 2         Name               Venusaur
# 3         Name  VenusaurMega Venusaur
# 4       Type 1                  Grass
# 5       Type 1                  Grass
# 6       Type 1                  Grass
# 7       Type 1                  Grass
# 8       Type 2                 Poison
# 9       Type 2                 Poison
# 10      Type 2                 Poison
# 11      Type 2                 Poison
# 12          HP                     45
# 13          HP                     60
# 14          HP                     80
# 15          HP                     80
# 16      Attack                     49
# 17      Attack                     62
# 18      Attack                     82
# 19      Attack                    100
# 20     Defense                     49
# 21     Defense                     63
# 22     Defense                     83
# 23     Defense                    123
# ...

# %%
pd.melt(df1,id_vars='Name').head(20)
# name is index here
# Out:
#                      Name variable   value
# 0               Bulbasaur   Type 1   Grass
# 1                 Ivysaur   Type 1   Grass
# 2                Venusaur   Type 1   Grass
# 3   VenusaurMega Venusaur   Type 1   Grass
# 4               Bulbasaur   Type 2  Poison
# 5                 Ivysaur   Type 2  Poison
# 6                Venusaur   Type 2  Poison
# 7   VenusaurMega Venusaur   Type 2  Poison
# 8               Bulbasaur       HP      45
# 9                 Ivysaur       HP      60
# 10               Venusaur       HP      80
# 11  VenusaurMega Venusaur       HP      80
# 12              Bulbasaur   Attack      49
# 13                Ivysaur   Attack      62
# 14               Venusaur   Attack      82
# 15  VenusaurMega Venusaur   Attack     100
# 16              Bulbasaur  Defense      49
# 17                Ivysaur  Defense      63
# 18               Venusaur  Defense      83
# 19  VenusaurMega Venusaur  Defense     123

# %%
pd.melt(df1,id_vars='Name',value_name='Anything i want to name').head(20)
# Out:
#                      Name variable Anything i want to name
# 0               Bulbasaur   Type 1                   Grass
# 1                 Ivysaur   Type 1                   Grass
# 2                Venusaur   Type 1                   Grass
# 3   VenusaurMega Venusaur   Type 1                   Grass
# 4               Bulbasaur   Type 2                  Poison
# 5                 Ivysaur   Type 2                  Poison
# 6                Venusaur   Type 2                  Poison
# 7   VenusaurMega Venusaur   Type 2                  Poison
# 8               Bulbasaur       HP                      45
# 9                 Ivysaur       HP                      60
# 10               Venusaur       HP                      80
# 11  VenusaurMega Venusaur       HP                      80
# 12              Bulbasaur   Attack                      49
# 13                Ivysaur   Attack                      62
# 14               Venusaur   Attack                      82
# ...

# %% [markdown]
# ### crosstab

# %%
pd.crosstab(df1['Name'],df1['Type 1'])
# Out:
# Type 1                 Grass
# Name
# Bulbasaur                  1
# Ivysaur                    1
# Venusaur                   1
# VenusaurMega Venusaur      1

# %%
pd.crosstab(df1['Name'],df1['Type 1'],margins=True)
# margin gives total of the row
# Out:
# Type 1                 Grass  All
# Name
# Bulbasaur                  1    1
# Ivysaur                    1    1
# Venusaur                   1    1
# VenusaurMega Venusaur      1    1
# All                        4    4

# %%
pd.crosstab(df1['Name'],[df1['Type 1'],df1['Type 2']])
# Out:
# Type 1                 Grass
# Type 2                Poison
# Name
# Bulbasaur                  1
# Ivysaur                    1
# Venusaur                   1
# VenusaurMega Venusaur      1

# %%
pd.crosstab([df1['Type 1'],df1['Type 2']],df1['Name'])
# Out:
# Name           Bulbasaur  Ivysaur  Venusaur  VenusaurMega Venusaur
# Type 1 Type 2
# Grass  Poison          1        1         1                      1

# %%
pd.crosstab(df1['Name'],df1['Type 1'],values=df1['Attack'],aggfunc=np.unique)
# Out:
# Type 1                 Grass
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100

# %%
pd.crosstab(index=[df1['Name']],columns=[df1['Type 1'],df1['Type 2']])
# Out:
# Type 1                 Grass
# Type 2                Poison
# Name
# Bulbasaur                  1
# Ivysaur                    1
# Venusaur                   1
# VenusaurMega Venusaur      1

# %% [markdown]
# #### Drop duplicates

# %%
df1
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df1.drop_duplicates(subset=['Speed'])
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df1.drop_duplicates(subset=['Type 1'])
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %%
df1.drop_duplicates(subset=['Type 1','Speed'])

# duplicates in Type 1 and Speed column both
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
# 1    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
df1.drop_duplicates(subset=['Type 1','Speed'])[['Name','Sp. Atk']]
# Out:
#         Name  Sp. Atk
# 0  Bulbasaur       65
# 1    Ivysaur       80
# 2   Venusaur      100

# %% [markdown]
# #### isin( )

# %%
new = df1["Name"].isin(["Bulbasaur"])
df1[new]
# Out:
#         Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  Bulbasaur  Grass  Poison  45      49       49       65       65     45
#
#    Generation  Legendary
# 0           1      False

# %% [markdown]
# #### correlation

# %%
df1.corr()
# Out:
#                   HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# HP          1.000000  0.938502  0.850616  0.927208  0.936003  1.000000
# Attack      0.938502  1.000000  0.979585  0.999196  0.999681  0.938502
# Defense     0.850616  0.979585  1.000000  0.985605  0.981229  0.850616
# Sp. Atk     0.927208  0.999196  0.985605  1.000000  0.999707  0.927208
# Sp. Def     0.936003  0.999681  0.981229  0.999707  1.000000  0.936003
# Speed       1.000000  0.938502  0.850616  0.927208  0.936003  1.000000
# Generation       NaN       NaN       NaN       NaN       NaN       NaN
# Legendary        NaN       NaN       NaN       NaN       NaN       NaN
#
#             Generation  Legendary
# HP                 NaN        NaN
# Attack             NaN        NaN
# Defense            NaN        NaN
# Sp. Atk            NaN        NaN
# Sp. Def            NaN        NaN
# Speed              NaN        NaN
# Generation         NaN        NaN
# Legendary          NaN        NaN

# %%
import seaborn as sns
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### rename column name

# %%
df1
# Out:
#                     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45      49       49       65
# 1                Ivysaur  Grass  Poison  60      62       63       80
# 2               Venusaur  Grass  Poison  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False

# %%
df1.rename(columns={'Name':'Pokemon_name','Attack':'Attack_power'})
# Out:
#             Pokemon_name Type 1  Type 2  HP  Attack_power  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison  45            49       49       65
# 1                Ivysaur  Grass  Poison  60            62       63       80
# 2               Venusaur  Grass  Poison  80            82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison  80           100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
